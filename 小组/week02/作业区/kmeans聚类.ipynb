# %% [markdown]
# # KMeans对iris数据集聚类
# [指路](https://github.com/TGMax233Michael/MyMLModule/blob/main/myMLModule/models/cluster.py)

# %%
from myMLModule.models.cluster import KMeans
from sklearn.datasets import load_iris

iris = load_iris()
X, y = iris["data"], iris["target"]
print(X.shape[1])

model = KMeans(n_clusters=3, n_epoches=5000)

model.fit(X)
y_pred = model.predict(X)
# Out:
# 4

# %% [markdown]
# ### 绘制出每对变量中聚类与原标签的散点图，查看差异

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(18, 12), dpi=80)
plt.subplot(3, 2, 1)
plt.scatter(X[:, 0], X[:, 1], c=y_pred, cmap="jet")

plt.subplot(3, 2, 2)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap="jet")

plt.subplot(3, 2, 3)
plt.scatter(X[:, 0], X[:, 2], c=y_pred, cmap="jet")

plt.subplot(3, 2, 4)
plt.scatter(X[:, 0], X[:, 2], c=y, cmap="jet")

plt.subplot(3, 2, 5)
plt.scatter(X[:, 0], X[:, 3], c=y_pred, cmap="jet")

plt.subplot(3, 2, 6)
plt.scatter(X[:, 0], X[:, 3], c=y, cmap="jet")

plt.show()
